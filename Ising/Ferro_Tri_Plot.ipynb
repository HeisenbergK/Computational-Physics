# %%
from Ising import Ising

# %%
T = 2.0
lattice = 64
iterations = 1500
model = Ising(T, lattice, iterations, mesh="tri", prop="ferro", plots=True)
model.simulate()
# Out:
# [-383405.9999999998, 6070]
