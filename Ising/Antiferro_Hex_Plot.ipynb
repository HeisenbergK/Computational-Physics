# %%
from Ising import Ising

# %%
T = 0.1
lattice = 64
iterations = 1500
model = Ising(T, lattice, iterations, prop="antiferro", mesh="hex", plots=True)
model.simulate()
# Out:
# [-2044355.9999999462, -596]
